# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot
import seaborn as sns

import numpy as np
import pandas as pd

# Data visualization
import matplotlib.pyplot as plt
from matplotlib import cm # Colomaps
import seaborn as sns

# Classifier algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

#train test split
from sklearn.model_selection import train_test_split

# Model evaluation
from sklearn import metrics
import tensorflow as tf

# %%
file_name = 'https://raw.githubusercontent.com/Pradeep-dev-ml/bank-markating/main/Data%20%20Set/bank-additional-full.csv'

# Load CSV File

data = pd.read_csv(file_name,'',';')
data.sample(20)
# Out:
#        age           job   marital            education  default housing loan  \
# 8943    40    technician   married             basic.9y  unknown     yes   no
# 9088    48        admin.  divorced    university.degree       no      no   no
# 24708   37  entrepreneur   married             basic.9y  unknown      no   no
# 20593   41    technician   married  professional.course       no     yes   no
# 13213   30   blue-collar   married          high.school  unknown     yes   no
# 26779   47   blue-collar   married             basic.6y       no     yes  yes
# 27041   50   blue-collar   married    university.degree  unknown      no   no
# 20906   34    technician   married    university.degree  unknown     yes   no
# 14443   38    technician    single  professional.course       no     yes   no
# 24417   39    management   married    university.degree       no      no   no
# 19095   32    technician    single    university.degree       no      no   no
# 10297   36    technician   married    university.degree       no      no   no
# 10027   53    technician   married              unknown       no     yes   no
# 17014   57        admin.   married    university.degree       no     yes   no
# 25228   32        admin.    single    university.degree       no     yes   no
# 12353   28   blue-collar  divorced             basic.4y       no      no   no
# 13526   23   blue-collar    single             basic.9y       no      no   no
# 29443   34      services    single             basic.6y       no     yes   no
# 15601   33        admin.    single    university.degree       no      no   no
# 16892   53   blue-collar   married              unknown       no      no  yes
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 8943   telephone   jun         thu  ...         2    999         0
# 9088   telephone   jun         fri  ...         4    999         0
# 24708  telephone   nov         mon  ...         1    999         0
# 20593   cellular   aug         tue  ...         2    999         0
# 13213   cellular   jul         wed  ...         1    999         0
# 26779   cellular   nov         thu  ...         6    999         0
# 27041   cellular   nov         fri  ...         1    999         0
# 20906   cellular   aug         thu  ...         1    999         0
# 14443   cellular   jul         tue  ...         2    999         0
# 24417   cellular   nov         mon  ...         1    999         1
# 19095   cellular   aug         tue  ...         1    999         0
# 10297  telephone   jun         mon  ...         1    999         0
# 10027  telephone   jun         thu  ...         3    999         0
# 17014   cellular   jul         thu  ...        10    999         0
# 25228   cellular   nov         tue  ...         2    999         1
# 12353  telephone   jul         fri  ...         1    999         0
# 13526   cellular   jul         thu  ...         1    999         0
# 29443   cellular   apr         mon  ...         1    999         0
# 15601   cellular   jul         mon  ...         4    999         0
# 16892   cellular   jul         thu  ...         1    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 8943   nonexistent          1.4          94.465          -41.8      4.866
# 9088   nonexistent          1.4          94.465          -41.8      4.967
# 24708  nonexistent         -0.1          93.200          -42.0      4.191
# 20593  nonexistent          1.4          93.444          -36.1      4.966
# 13213  nonexistent          1.4          93.918          -42.7      4.962
# 26779  nonexistent         -0.1          93.200          -42.0      4.076
# 27041  nonexistent         -0.1          93.200          -42.0      4.021
# 20906  nonexistent          1.4          93.444          -36.1      4.964
# 14443  nonexistent          1.4          93.918          -42.7      4.961
# 24417      failure         -0.1          93.200          -42.0      4.191
# 19095  nonexistent          1.4          93.444          -36.1      4.968
# 10297  nonexistent          1.4          94.465          -41.8      4.960
# 10027  nonexistent          1.4          94.465          -41.8      4.958
# 17014  nonexistent          1.4          93.918          -42.7      4.962
# 25228      failure         -0.1          93.200          -42.0      4.153
# 12353  nonexistent          1.4          93.918          -42.7      4.959
# 13526  nonexistent          1.4          93.918          -42.7      4.963
# 29443  nonexistent         -1.8          93.075          -47.1      1.405
# 15601  nonexistent          1.4          93.918          -42.7      4.960
# 16892  nonexistent          1.4          93.918          -42.7      4.962
#
#        nr.employed    y
# 8943        5228.1   no
# 9088        5228.1   no
# 24708       5195.8   no
# 20593       5228.1   no
# 13213       5228.1   no
# 26779       5195.8   no
# 27041       5195.8   no
# 20906       5228.1   no
# 14443       5228.1   no
# 24417       5195.8   no
# 19095       5228.1   no
# 10297       5228.1  yes
# 10027       5228.1   no
# 17014       5228.1   no
# 25228       5195.8   no
# 12353       5228.1   no
# 13526       5228.1   no
# 29443       5099.1   no
# 15601       5228.1   no
# 16892       5228.1   no
#
# [20 rows x 21 columns]

# %%
def pre_processing(data):
    data2=data
    dummy_column = pd.get_dummies(data2['job'], prefix='job', drop_first=False, dummy_na=False)
    data2=pd.concat([data2, dummy_column], join='outer', axis=1)
    
    dummy_column = pd.get_dummies(data2['education'], prefix='education', drop_first=False, dummy_na=False)
    data2=pd.concat([data2, dummy_column], join='outer', axis=1)
    
    dummy_column = pd.get_dummies(data2['marital'], prefix='marital', drop_first=False, dummy_na=False)
    data2=pd.concat([data2, dummy_column], join='outer', axis=1)
    
    data2['default'].value_counts()
    dummy_column = pd.get_dummies(data2['default'], prefix='default', drop_first=False, dummy_na=False)
    data2=pd.concat([data2, dummy_column], join='outer', axis=1)
    
    data2['housing'].value_counts().unique
    dummy_column = pd.get_dummies(data2['housing'], prefix='housing', drop_first=False, dummy_na=False)
    
    data2=pd.concat([data2, dummy_column], join='outer', axis=1)
    dummy_column = pd.get_dummies(data2['loan'], prefix='loan', drop_first=False, dummy_na=False)
    data2=pd.concat([data2, dummy_column], join='outer', axis=1)
    
    dummy_column = pd.get_dummies(data2['poutcome'], prefix='poutcome', drop_first=False, dummy_na=False)
    data2=pd.concat([data2, dummy_column], join='outer', axis=1)

    return data2

# %%
def model_train(model, model_name, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)
    y_pred_prob = model.predict_proba(X_test)[:, 1]
    test_result = pd.DataFrame(data={'y_act':y_test, 'y_pred':y_pred, 'y_pred_prob':y_pred_prob})

    accuracy = metrics.accuracy_score(test_result['y_act'], test_result['y_pred']) 
    precision = metrics.precision_score(test_result['y_act'], test_result['y_pred'], average='binary',pos_label='yes')
    f1_score = metrics.f1_score(test_result['y_act'], test_result['y_pred'], average='weighted',)  #weighted accounts for label imbalance.
    roc_auc = metrics.roc_auc_score(test_result['y_act'], test_result['y_pred_prob'])

    return ({'model_name':model_name, 
                   'model':model, 
                   'accuracy':accuracy, 
                   'precision':precision,
                  'f1_score':f1_score,
                  'roc_auc':roc_auc,
                  })

# %%
TrainingDataFrame=pre_processing(data)

# %%
X=TrainingDataFrame[['age','duration', 'campaign', 'pdays',
       'previous', 'emp.var.rate', 'cons.price.idx',
       'cons.conf.idx', 'euribor3m', 'nr.employed', 'job_admin.',
       'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
       'job_management', 'job_retired', 'job_self-employed',
       'job_services', 'job_student', 'job_technician', 'job_unemployed',
       'job_unknown', 'education_basic.4y', 'education_basic.6y',
       'education_basic.9y', 'education_high.school',
       'education_illiterate', 'education_professional.course',
       'education_university.degree', 'education_unknown',
       'marital_divorced', 'marital_married', 'marital_single',
       'marital_unknown', 'default_no', 'default_unknown', 'default_yes',
       'housing_no', 'housing_unknown', 'housing_yes', 'loan_no',
       'loan_unknown', 'loan_yes', 'poutcome_failure',
       'poutcome_nonexistent', 'poutcome_success']]
Y=TrainingDataFrame['y']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y,test_size=0.2,train_size=0.8, random_state=42)

# %%
model_train(LogisticRegression(max_iter=10000),'Logistic Regrassion',X_train,y_train, X_test,y_test)
# Out:
# {'model_name': 'Logistic Regrassion',
#  'model': LogisticRegression(max_iter=10000),
#  'accuracy': 0.9118718135469774,
#  'precision': 0.6843033509700176,
#  'f1_score': 0.9021587334788228,
#  'roc_auc': 0.9288514499572001}

# %%
from sklearn.neighbors import KNeighborsClassifier
model_train(KNeighborsClassifier(n_neighbors=3),'Logistic Regrassion',X_train,y_train, X_test,y_test)
# Out:
# {'model_name': 'Logistic Regrassion',
#  'model': KNeighborsClassifier(n_neighbors=3),
#  'accuracy': 0.8954843408594318,
#  'precision': 0.5463659147869674,
#  'f1_score': 0.8918387762155449,
#  'roc_auc': 0.8340758065142082}

# %%
from sklearn.neighbors import KNeighborsClassifier
model_train(KNeighborsClassifier(n_neighbors=6),'KNeighborsClassifier',X_train,y_train, X_test,y_test)
# Out:
# {'model_name': 'KNeighborsClassifier',
#  'model': KNeighborsClassifier(n_neighbors=6),
#  'accuracy': 0.9050740470988103,
#  'precision': 0.6321243523316062,
#  'f1_score': 0.8950429798349032,
#  'roc_auc': 0.8796737257635678}

# %%
from sklearn.neighbors import KNeighborsClassifier
model_train(KNeighborsClassifier(n_neighbors=9),'Logistic Regrassion',X_train,y_train, X_test,y_test)
# Out:
# {'model_name': 'Logistic Regrassion',
#  'model': KNeighborsClassifier(n_neighbors=9),
#  'accuracy': 0.9068948773974266,
#  'precision': 0.6141304347826086,
#  'f1_score': 0.9019766477050184,
#  'roc_auc': 0.8992025107255754}

# %%
from sklearn.neighbors import KNeighborsClassifier
model_train(KNeighborsClassifier(n_neighbors=30),'Logistic Regrassion',X_train,y_train, X_test,y_test)
# Out:
# {'model_name': 'Logistic Regrassion',
#  'model': KNeighborsClassifier(n_neighbors=30),
#  'accuracy': 0.9129643117261471,
#  'precision': 0.6631736526946108,
#  'f1_score': 0.906497094385472,
#  'roc_auc': 0.92710482323212}

# %%
from sklearn.neighbors import KNeighborsClassifier
model_train(KNeighborsClassifier(n_neighbors=800),'Logistic Regrassion',X_train,y_train, X_test,y_test)
# Out:
# {'model_name': 'Logistic Regrassion',
#  'model': KNeighborsClassifier(n_neighbors=800),
#  'accuracy': 0.9019179412478757,
#  'precision': 0.6104347826086957,
#  'f1_score': 0.8914056988024234,
#  'roc_auc': 0.9270841006662709}

# %%
from sklearn.tree import DecisionTreeClassifier
model_train(DecisionTreeClassifier(criterion='entropy', random_state=20),'DecisionTreeClassifier',X_train,y_train, X_test,y_test)
# Out:
# {'model_name': 'DecisionTreeClassifier',
#  'model': DecisionTreeClassifier(criterion='entropy', random_state=20),
#  'accuracy': 0.884316581694586,
#  'precision': 0.49072164948453606,
#  'f1_score': 0.8852403526582137,
#  'roc_auc': 0.7207237374428939}

# %%
modelTest=LogisticRegression(max_iter=10000)
modelTest.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
testdata=pre_processing(data)

# %%
X_test=testdata[['age','duration', 'campaign', 'pdays',
       'previous', 'emp.var.rate', 'cons.price.idx',
       'cons.conf.idx', 'euribor3m', 'nr.employed', 'job_admin.',
       'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
       'job_management', 'job_retired', 'job_self-employed',
       'job_services', 'job_student', 'job_technician', 'job_unemployed',
       'job_unknown', 'education_basic.4y', 'education_basic.6y',
       'education_basic.9y', 'education_high.school',
       'education_illiterate', 'education_professional.course',
       'education_university.degree', 'education_unknown',
       'marital_divorced', 'marital_married', 'marital_single',
       'marital_unknown', 'default_no', 'default_unknown', 'default_yes',
       'housing_no', 'housing_unknown', 'housing_yes', 'loan_no',
       'loan_unknown', 'loan_yes', 'poutcome_failure',
       'poutcome_nonexistent', 'poutcome_success']]

# %%
Y_Predicted = modelTest.predict(X_test)

# %%
test_result = pd.DataFrame(data={'y_act':testdata['y'],'y_predicted':Y_Predicted,'index_A':testdata.index})
test_result.head(100)
# Out:
#    y_act y_predicted  index_A
# 0     no          no        0
# 1     no          no        1
# 2     no          no        2
# 3     no          no        3
# 4     no          no        4
# ..   ...         ...      ...
# 95    no          no       95
# 96    no          no       96
# 97    no          no       97
# 98    no          no       98
# 99    no          no       99
#
# [100 rows x 3 columns]

# %%
    wrong=[]
    for index, row in test_result.iterrows():
    
        if (row['y_act']!=row['y_predicted']):
            wrong.append(row['index_A'])

# %%
print(len(wrong))
# Out:
# 3701

# %%
len(data)
# Out:
# 41188

# %%
print(wrong)
# Out:
# [37, 129, 139, 164, 182, 199, 286, 504, 590, 719, 832, 840, 870, 876, 943, 981, 1001, 1077, 1113, 1166, 1189, 1305, 1319, 1348, 1367, 1501, 1538, 1608, 1613, 1632, 1636, 1655, 1689, 1691, 1725, 1763, 1766, 1819, 1839, 1852, 1853, 1906, 1984, 2000, 2002, 2039, 2064, 2076, 2105, 2132, 2257, 2294, 2305, 2313, 2315, 2316, 2367, 2406, 2421, 2424, 2444, 2449, 2465, 2473, 2575, 2624, 2629, 2635, 2654, 2684, 2697, 2713, 2755, 2775, 2779, 2853, 2905, 2929, 3040, 3083, 3090, 3113, 3144, 3183, 3210, 3219, 3223, 3259, 3261, 3264, 3338, 3381, 3407, 3453, 3506, 3541, 3545, 3564, 3566, 3570, 3608, 3628, 3661, 3677, 3693, 3697, 3740, 3765, 3807, 3822, 3823, 3829, 3855, 3887, 3891, 3892, 3939, 3979, 3988, 4034, 4049, 4050, 4110, 4164, 4167, 4213, 4294, 4397, 4410, 4420, 4485, 4522, 4526, 4623, 4635, 4672, 4677, 4694, 4700, 4720, 4737, 4752, 4769, 4793, 4836, 4851, 4872, 4899, 4901, 4904, 4982, 4993, 5007, 5027, 5056, 5081, 5084, 5107, 5112, 5162, 5174, 5273, 5329, 5347, 5363, 5384, 5386, 5442, 5467, 5550, 5597, 5613, 5619, 5636, 5638, 5652, 5707, 5731, 5780, 5784, 5818, 5850, 5852, 5863, 6018, 6104, 6143, 6164, 6203, 6213, 6264, 6320, 6362, 6394, 6406, 6466, 6520, 6573, 6585, 6605, 6629, 6648, 6662, 6678, 6695, 6762, 6803, 6860, 6901, 6928, 6937, 6959, 6982, 7009, 7095, 7099, 7162, 7201, 7216, 7266, 7289, 7297, 7359, 7397, 7404, 7419, 7437, 7444, 7445, 7470, 7475, 7478, 7542, 7544, 7558, 7571, 7620, 7652, 7717, 7719, 7725, 7731, 7760, 7793, 7808, 7811, 7814, 7817, 7819, 7835, 7881, 7952, 7983, 8014, 8016, 8062, 8102, 8112, 8130, 8135, 8180, 8196, 8233, 8246, 8276, 8279, 8315, 8350, 8355, 8360, 8379, 8417, 8482, 8502, 8528, 8535, 8542, 8554, 8568, 8596, 8599, 8603, 8607, 8621, 8661, 8804, 8817, 8826, 8866, 8883, 8897, 8906, 8912, 8958, 8977, 9003, 9028, 9101, 9150, 9157, 9160, 9196, 9203, 9204, 9205, 9215, 9239, 9256, 9258, 9338, 9346, 9365, 9447, 9471, 9524, 9547, 9572, 9585, 9636, 9650, 9705, 9708, 9733, 9741, 9792, 9796, 9811, 9840, 9841, 9852, 9901, 9904, 9907, 9911, 9914, 9998, 10034, 10049, 10076, 10124, 10134, 10144, 10157, 10160, 10162, 10227, 10239, 10247, 10310, 10329, 10332, 10402, 10418, 10544, 10635, 10658, 10661, 10663, 10666, 10685, 10704, 10790, 10825, 10835, 10848, 10893, 10914, 10916, 10936, 10977, 10979, 11016, 11017, 11020, 11046, 11070, 11100, 11145, 11172, 11233, 11241, 11255, 11274, 11317, 11345, 11346, 11348, 11360, 11417, 11444, 11449, 11450, 11471, 11473, 11492, 11535, 11552, 11564, 11567, 11690, 11708, 11716, 11717, 11737, 11752, 11790, 11931, 11933, 11936, 11937, 11947, 11961, 12002, 12004, 12023, 12039, 12041, 12057, 12133, 12139, 12187, 12191, 12195, 12264, 12322, 12349, 12384, 12385, 12387, 12404, 12425, 12455, 12458, 12461, 12466, 12501, 12506, 12526, 12565, 12568, 12573, 12586, 12596, 12605, 12707, 12758, 12766, 12767, 12785, 12803, 12806, 12809, 12823, 12826, 12843, 12866, 12878, 12887, 12904, 12931, 12932, 12971, 12979, 12982, 12983, 13011, 13016, 13031, 13120, 13129, 13131, 13134, 13176, 13186, 13189, 13217, 13218, 13223, 13224, 13231, 13258, 13269, 13276, 13281, 13284, 13293, 13359, 13409, 13431, 13460, 13494, 13504, 13518, 13531, 13542, 13551, 13585, 13595, 13620, 13627, 13685, 13700, 13705, 13710, 13726, 13727, 13732, 13734, 13792, 13799, 13807, 13834, 13836, 13882, 13891, 13925, 13942, 13977, 13978, 13983, 14000, 14002, 14029, 14050, 14054, 14067, 14069, 14076, 14103, 14137, 14177, 14220, 14222, 14236, 14262, 14278, 14341, 14356, 14382, 14410, 14424, 14465, 14477, 14479, 14482, 14492, 14520, 14554, 14576, 14582, 14591, 14592, 14596, 14597, 14598, 14618, 14633, 14639, 14684, 14686, 14695, 14711, 14712, 14722, 14729, 14740, 14746, 14755, 14787, 14788, 14789, 14795, 14803, 14805, 14813, 14815, 14821, 14828, 14864, 14871, 14879, 14884, 14888, 14892, 14909, 14919, 14944, 14948, 14955, 14962, 15010, 15045, 15058, 15110, 15121, 15126, 15128, 15155, 15190, 15194, 15197, 15209, 15210, 15211, 15215, 15255, 15269, 15294, 15316, 15317, 15319, 15344, 15345, 15346, 15353, 15357, 15368, 15378, 15387, 15394, 15403, 15410 ...

# %%
testdata.iloc[37]
# Out:
# 0

# %%
Filter_df  = testdata[testdata.index.isin(wrong)]

# %%
Filter_df.head(100)
# Out:
#       age           job   marital            education  default  housing  \
# 37     52    technician   married             basic.9y       no      yes
# 129    41    technician   married  professional.course  unknown      yes
# 139    45   blue-collar   married             basic.9y  unknown      yes
# 164    39      services  divorced          high.school  unknown       no
# 182    42   blue-collar   married             basic.9y       no      yes
# ...   ...           ...       ...                  ...      ...      ...
# 3541   45  entrepreneur   married    university.degree       no      yes
# 3545   35        admin.    single          high.school       no       no
# 3564   29   blue-collar    single          high.school       no      yes
# 3566   44    management    single    university.degree  unknown      yes
# 3570   31   blue-collar   married             basic.6y  unknown  unknown
#
#          loan    contact month day_of_week  ...  default_yes  housing_no  \
# 37         no  telephone   may         mon  ...            0           0
# 129        no  telephone   may         mon  ...            0           0
# 139        no  telephone   may         mon  ...            0           0
# 164        no  telephone   may         mon  ...            0           1
# 182       yes  telephone   may         mon  ...            0           0
# ...       ...        ...   ...         ...  ...          ...         ...
# 3541      yes  telephone   may         fri  ...            0           0
# 3545      yes  telephone   may         fri  ...            0           1
# 3564       no  telephone   may         fri  ...            0           0
# 3566       no  telephone   may         fri  ...            0           0
# 3570  unknown  telephone   may         fri  ...            0           0
#
#       housing_unknown  housing_yes loan_no  loan_unknown  loan_yes  \
# 37                  0            1       1             0         0
# 129                 0            1       1             0         0
# 139                 0            1       1             0         0
# 164                 0            0       1             0         0
# 182                 0            1       0             0         1
# ...               ...          ...     ...           ...       ...
# 3541                0            1       0             0         1
# 3545                0            0       0             0         1
# 3564                0            1       1             0         0
# 3566                0            1       1             0         0
# 3570                1            0       0             1         0
#
#       poutcome_failure  poutcome_nonexistent  poutcome_success
# 37                   0                     1                 0
# 129                  0                     1                 0
# 139                  0                     1                 0
# 164                  0                     1                 0
# 182                  0                     1                 0
# ...                ...                   ...               ...
# 3541                 0                     1                 0
# 3545                 0                     1                 0
# 3564                 0                     1                 0
# 3566                 0                     1                 0
# 3570                 0                     1                 0
#
# [100 rows x 57 columns]
